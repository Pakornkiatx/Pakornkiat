# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakornkiatx/Pakornkiat/blob/main/Lab3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GTS123 Lab 3.1

import numpy as np
import matplotlib.pyplot as plt
from math import*
plt.xlim(-3*pi,3*pi)
x = np.arange(-3*pi,3*pi,0.1)
y1 = np.sin(x)
y2 = np.sin(x+0.5)
y3 = np.sin(x+1)
y4 = np.sin(x+1.5)

plt.plot(x, y1, color="pink", linestyle="solid")
plt.plot(x, y2, color="orange", linestyle="dashdot")
plt.plot(x, y3, color="green", linestyle="dashed")
plt.plot(x, y4, color="blue", linestyle="dotted")
print(x)
print(y1)
print(y2)
print(y3)
print(y4)
plt.show()
# Out:
# [-9.42477796 -9.32477796 -9.22477796 -9.12477796 -9.02477796 -8.92477796
#  -8.82477796 -8.72477796 -8.62477796 -8.52477796 -8.42477796 -8.32477796
#  -8.22477796 -8.12477796 -8.02477796 -7.92477796 -7.82477796 -7.72477796
#  -7.62477796 -7.52477796 -7.42477796 -7.32477796 -7.22477796 -7.12477796
#  -7.02477796 -6.92477796 -6.82477796 -6.72477796 -6.62477796 -6.52477796
#  -6.42477796 -6.32477796 -6.22477796 -6.12477796 -6.02477796 -5.92477796
#  -5.82477796 -5.72477796 -5.62477796 -5.52477796 -5.42477796 -5.32477796
#  -5.22477796 -5.12477796 -5.02477796 -4.92477796 -4.82477796 -4.72477796
#  -4.62477796 -4.52477796 -4.42477796 -4.32477796 -4.22477796 -4.12477796
#  -4.02477796 -3.92477796 -3.82477796 -3.72477796 -3.62477796 -3.52477796
#  -3.42477796 -3.32477796 -3.22477796 -3.12477796 -3.02477796 -2.92477796
#  -2.82477796 -2.72477796 -2.62477796 -2.52477796 -2.42477796 -2.32477796
#  -2.22477796 -2.12477796 -2.02477796 -1.92477796 -1.82477796 -1.72477796
# ...
